# %%
import pandas as pd
import numpy
import math
import os
import datetime
import math
import seaborn as sns
import matplotlib.pyplot as plt
import kagglehub

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# # LOADING DATA SET

# %%
df = pd.read_csv(r'C:\Users\PMLS\Desktop\SEM-5\Into to DS\Intro to DS\Assignment7\Employe_Performance_dataset.csv')

# %% [markdown]
# ### TASK - 1
# ___

# %%
df.head(10)
# Out:
#    ID                Name  Age  Gender Department  Salary Joining Date  \
# 0   1        Cory Escobar   48  Female         HR    5641   2015-05-03
# 1   2     Timothy Sanchez   25   Other      Sales    4249   2020-11-09
# 2   3        Chad Nichols   57   Other      Sales    3058   2019-02-12
# 3   4  Christine Williams   58  Female         IT    5895   2017-09-08
# 4   5        Amber Harris   35   Other         IT    4317   2020-02-15
# 5   6         Ashley Howe   29  Female         HR    2591   2016-06-24
# 6   7         David Olson   39  Female      Sales    6826   2023-05-11
# 7   8        Amanda Baker   52   Other         HR    6285   2015-04-01
# 8   9       Jeremy Wright   63  Female      Sales    9862   2024-02-07
# 9  10      Brian Faulkner   30    Male         IT    8202   2018-05-26
#
#    Performance Score  Experience    Status     Location  Session
# 0                2.0          16    Active     New York    Night
# ...

# %% [markdown]
# ### TASK - 2
# ##### Displaying the data types of each column
# ___

# %%
df.dtypes
# Out:
# ID                     int64
# Name                  object
# Age                    int64
# Gender                object
# Department            object
# Salary                 int64
# Joining Date          object
# Performance Score    float64
# Experience             int64
# Status                object
# Location              object
# Session               object
# dtype: object

# %% [markdown]
# ### TASK - 3
# ##### Displaying the number of rows and columns in the data frame
# ___

# %%
rows,cols = df.shape
print(f'Data Frame contains {rows} number of rows.')
print(f'Data Frame contain {cols} number of columns.')
# Out:
# Data Frame contains 1000 number of rows.
# Data Frame contain 12 number of columns.

# %% [markdown]
# ### TASK - 4
# ##### Displaying the columns 'Name', 'Age' and 'Salary'
# ___

# %%
print(df[['Name', 'Age', 'Salary']])
# Out:
#                    Name  Age  Salary
# 0          Cory Escobar   48    5641
# 1       Timothy Sanchez   25    4249
# 2          Chad Nichols   57    3058
# 3    Christine Williams   58    5895
# 4          Amber Harris   35    4317
# ..                  ...  ...     ...
# 995       Pamela Reeves   49    7652
# 996        Todd Johnson   29    6754
# 997     Michael Sanchez   18    5278
# 998       Ashley Taylor   51    5437
# 999         Shawn Scott   45    7364
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### TASK - 5
# ##### Displaying the first 5 rows of the data frame.
#
# ---

# %%
df.iloc[:5]
# Out:
#    ID                Name  Age  Gender Department  Salary Joining Date  \
# 0   1        Cory Escobar   48  Female         HR    5641   2015-05-03
# 1   2     Timothy Sanchez   25   Other      Sales    4249   2020-11-09
# 2   3        Chad Nichols   57   Other      Sales    3058   2019-02-12
# 3   4  Christine Williams   58  Female         IT    5895   2017-09-08
# 4   5        Amber Harris   35   Other         IT    4317   2020-02-15
#
#    Performance Score  Experience    Status     Location  Session
# 0                2.0          16    Active     New York    Night
# 1                2.0          11  Inactive  Los Angeles  Evening
# 2                NaN           1  Inactive     New York  Morning
# 3                2.0          13  Inactive  Los Angeles  Evening
# 4                5.0          16  Inactive     New York  Evening

# %% [markdown]
# ### TASK - 6
# ##### Displaying the rows where the 'Department' is 'Sales'
#
# ___

# %%
df.loc[df['Department'] == 'Sales']
# Out:
#       ID             Name  Age  Gender Department  Salary Joining Date  \
# 1      2  Timothy Sanchez   25   Other      Sales    4249   2020-11-09
# 2      3     Chad Nichols   57   Other      Sales    3058   2019-02-12
# 6      7      David Olson   39  Female      Sales    6826   2023-05-11
# 8      9    Jeremy Wright   63  Female      Sales    9862   2024-02-07
# 10    11      Nicole Bell   42  Female      Sales    5336   2015-01-28
# ..   ...              ...  ...     ...        ...     ...          ...
# 991  992  William Schultz   23   Other      Sales    4311   2019-08-17
# 992  993   Ashley Daniels   25   Other      Sales    5524   2022-11-24
# 995  996    Pamela Reeves   49  Female      Sales    7652   2024-06-23
# 996  997     Todd Johnson   29  Female      Sales    6754   2018-07-20
# 997  998  Michael Sanchez   18    Male      Sales    5278   2023-07-05
#
#      Performance Score  Experience    Status     Location  Session
# ...

# %% [markdown]
# ### TASK - 7
# ##### Displaying the rows where the 'Salary' is greater than 8000 and 'Status' is 'Active'
# ___

# %%
df[(df['Salary'] > 8000) & (df['Status'] == 'Active')]
# Out:
#       ID             Name  Age  Gender Department  Salary Joining Date  \
# 9     10   Brian Faulkner   30    Male         IT    8202   2018-05-26
# 24    25    Tracy Carlson   21    Male         HR    9275   2022-04-09
# 38    39     Jordan Scott   33   Other      Sales    8678   2016-05-15
# 39    40      Lisa Wagner   36    Male         HR    8870   2024-08-12
# 60    61   Andrew Shannon   51   Other      Sales    8544   2020-02-08
# ..   ...              ...  ...     ...        ...     ...          ...
# 976  977    Kimberly Ross   19    Male      Sales    9331   2018-07-03
# 982  983    Stephen Ponce   46   Other      Sales    8696   2022-10-14
# 986  987  Melissa Bradley   39  Female         IT    9618   2015-07-05
# 988  989   Hannah Hickman   36  Female         IT    9118   2022-07-02
# 989  990    Shannon Meyer   18   Other         HR    9985   2022-11-05
#
#      Performance Score  Experience  Status     Location  Session
# ...

# %% [markdown]
# ### TASK - 8
# ##### Displaying the rows where the 'YearsWithCompany' is greater than 5 and 'Performance Score' is greater than or equal to 4
# ___

# %%
df['Joining Date'] = pd.to_datetime(df['Joining Date'])
current_date = datetime.datetime.now()
df['YearsWithCompany'] = (current_date - df['Joining Date']).dt.days // 365
df[(df['YearsWithCompany'] > 5) & (df['Performance Score'] >= 4)]
# Out:
#       ID                Name  Age  Gender Department  Salary Joining Date  \
# 11    12   Rodney Richardson   60   Other         HR    6908   2015-03-14
# 17    18  Jacqueline Randall   31  Female         HR    3519   2018-05-18
# 18    19      Nancy Stephens   38    Male         HR    9061   2017-07-16
# 22    23        Bryce Carter   35  Female      Sales    9598   2015-12-16
# 34    35            Lisa Fry   51  Female         IT    9259   2017-09-26
# ..   ...                 ...  ...     ...        ...     ...          ...
# 918  919     Tammy Schneider   22   Other         IT    3625   2016-10-24
# 937  938       Gary Mitchell   52  Female      Sales    9963   2016-09-22
# 972  973       James Mendoza   23   Other      Sales    6871   2016-04-11
# 976  977       Kimberly Ross   19    Male      Sales    9331   2018-07-03
# 993  994       Brandon Bruce   31  Female         HR    3371   2018-09-25
#
#      Performance Score  Experience    Status     Location  Session  \
# ...

# %% [markdown]
# ### TASK - 9
# ##### Display alternate row from the DataFrame using slicing with iloc.
# ___

# %%
df.iloc[::2]
# Out:
#       ID             Name  Age  Gender Department  Salary Joining Date  \
# 0      1     Cory Escobar   48  Female         HR    5641   2015-05-03
# 2      3     Chad Nichols   57   Other      Sales    3058   2019-02-12
# 4      5     Amber Harris   35   Other         IT    4317   2020-02-15
# 6      7      David Olson   39  Female      Sales    6826   2023-05-11
# 8      9    Jeremy Wright   63  Female      Sales    9862   2024-02-07
# ..   ...              ...  ...     ...        ...     ...          ...
# 990  991     Amy Johnston   53  Female         HR    3991   2024-09-03
# 992  993   Ashley Daniels   25   Other      Sales    5524   2022-11-24
# 994  995  Rachel Phillips   22    Male         IT    3096   2018-10-27
# 996  997     Todd Johnson   29  Female      Sales    6754   2018-07-20
# 998  999    Ashley Taylor   51  Female         IT    5437   2022-02-18
#
#      Performance Score  Experience    Status     Location  Session  \
# ...

# %% [markdown]
# ### TASK - 10
# #####  Displaying Employees who belongs to "Sales" and has a Salary in the top 10% of all salaries.
# ___

# %%
threshold = df['Salary'].quantile(0.9)
print(df[(df['Department'] == 'Sales') & (df['Salary'] >= threshold)])
# Out:
#       ID                     Name  Age  Gender Department  Salary  \
# 8      9            Jeremy Wright   63  Female      Sales    9862
# 22    23             Bryce Carter   35  Female      Sales    9598
# 29    30            Rachel Ramsey   22    Male      Sales    9661
# 215  216               Sara Jones   50  Female      Sales    9377
# 228  229          Christie Warren   51  Female      Sales    9139
# 239  240      Christina Gutierrez   37    Male      Sales    9356
# 250  251           Joshua Bullock   38    Male      Sales    9924
# 263  264          Gabriela Wilson   40   Other      Sales    9455
# 275  276          Harry Alexander   22    Male      Sales    9749
# 299  300              Terry Smith   38  Female      Sales    9375
# 379  380                Dustin Le   29    Male      Sales    9726
# 381  382           David Marshall   43   Other      Sales    9269
# 405  406            Heather Scott   57    Male      Sales    9505
# ...

# %% [markdown]
# ### TASK - 11
# ##### Replacing 'Inactive' with 'Retired' in the 'Status' column.
# ___

# %%
df['Status'] = df['Status'].replace('Inactive', 'Retired')
df.head(3)
# Out:
#    ID             Name  Age  Gender Department  Salary Joining Date  \
# 0   1     Cory Escobar   48  Female         HR    5641   2015-05-03
# 1   2  Timothy Sanchez   25   Other      Sales    4249   2020-11-09
# 2   3     Chad Nichols   57   Other      Sales    3058   2019-02-12
#
#    Performance Score  Experience   Status     Location  Session  \
# 0                2.0          16   Active     New York    Night
# 1                2.0          11  Retired  Los Angeles  Evening
# 2                NaN           1  Retired     New York  Morning
#
#    YearsWithCompany
# 0                 9
# 1                 4
# 2                 5

# %% [markdown]
# ### TASK - 12
# ##### Adding a new column 'Bonus' which is 10% of the 'Salary'
# ___

# %%
df['Bonus'] = df['Salary'] * 0.10
df.head(3)
# Out:
#    ID             Name  Age  Gender Department  Salary Joining Date  \
# 0   1     Cory Escobar   48  Female         HR    5641   2015-05-03
# 1   2  Timothy Sanchez   25   Other      Sales    4249   2020-11-09
# 2   3     Chad Nichols   57   Other      Sales    3058   2019-02-12
#
#    Performance Score  Experience   Status     Location  Session  \
# 0                2.0          16   Active     New York    Night
# 1                2.0          11  Retired  Los Angeles  Evening
# 2                NaN           1  Retired     New York  Morning
#
#    YearsWithCompany  Bonus
# 0                 9  564.1
# 1                 4  424.9
# 2                 5  305.8

# %% [markdown]
# ### TASK - 13
# ##### Replacing the missing values in 'Performance Score' column with 5 where the 'Department' is 'IT'
# ___

# %%
df.loc[(df['Department'] == 'IT') & (df['Performance Score'].isna()), 'Performance Score'] = 5
df.head(3)
# Out:
#    ID             Name  Age  Gender Department  Salary Joining Date  \
# 0   1     Cory Escobar   48  Female         HR    5641   2015-05-03
# 1   2  Timothy Sanchez   25   Other      Sales    4249   2020-11-09
# 2   3     Chad Nichols   57   Other      Sales    3058   2019-02-12
#
#    Performance Score  Experience   Status     Location  Session  \
# 0                2.0          16   Active     New York    Night
# 1                2.0          11  Retired  Los Angeles  Evening
# 2                NaN           1  Retired     New York  Morning
#
#    YearsWithCompany  Bonus
# 0                 9  564.1
# 1                 4  424.9
# 2                 5  305.8

# %% [markdown]
# ### TASK - 14
# ##### Replacing the values in 'Experience' column which are less than 2 with 2.
# ___

# %%
df.loc[df['Experience'] < 2, 'Experience'] = 2
df.head(3)
# Out:
#    ID             Name  Age  Gender Department  Salary Joining Date  \
# 0   1     Cory Escobar   48  Female         HR    5641   2015-05-03
# 1   2  Timothy Sanchez   25   Other      Sales    4249   2020-11-09
# 2   3     Chad Nichols   57   Other      Sales    3058   2019-02-12
#
#    Performance Score  Experience   Status     Location  Session  \
# 0                2.0          16   Active     New York    Night
# 1                2.0          11  Retired  Los Angeles  Evening
# 2                NaN           2  Retired     New York  Morning
#
#    YearsWithCompany  Bonus
# 0                 9  564.1
# 1                 4  424.9
# 2                 5  305.8

# %% [markdown]
# ### TASK - 15
# ##### Normalizing the 'Salary' column between 0 and 1.
# ___

# %%
df['Salary_Normalized'] = (df['Salary'] - df['Salary'].min()) / (df['Salary'].max() - df['Salary'].min())
df.head(3)
# Out:
#    ID             Name  Age  Gender Department  Salary Joining Date  \
# 0   1     Cory Escobar   48  Female         HR    5641   2015-05-03
# 1   2  Timothy Sanchez   25   Other      Sales    4249   2020-11-09
# 2   3     Chad Nichols   57   Other      Sales    3058   2019-02-12
#
#    Performance Score  Experience   Status     Location  Session  \
# 0                2.0          16   Active     New York    Night
# 1                2.0          11  Retired  Los Angeles  Evening
# 2                NaN           2  Retired     New York  Morning
#
#    YearsWithCompany  Bonus  Salary_Normalized
# 0                 9  564.1           0.454500
# 1                 4  424.9           0.280020
# 2                 5  305.8           0.130735

# %% [markdown]
# ### TASK - 16
# ##### Adding a new column 'Location' and setting the value to 'Remote' where the 'Performance Score' is less than 3.
# ___

# %%
df.loc[df['Performance Score'] < 3, 'Location'] = 'Remote'
df.head(5)
# Out:
#    ID                Name  Age  Gender Department  Salary Joining Date  \
# 0   1        Cory Escobar   48  Female         HR    5641   2015-05-03
# 1   2     Timothy Sanchez   25   Other      Sales    4249   2020-11-09
# 2   3        Chad Nichols   57   Other      Sales    3058   2019-02-12
# 3   4  Christine Williams   58  Female         IT    5895   2017-09-08
# 4   5        Amber Harris   35   Other         IT    4317   2020-02-15
#
#    Performance Score  Experience   Status  Location  Session  \
# 0                2.0          16   Active    Remote    Night
# 1                2.0          11  Retired    Remote  Evening
# 2                NaN           2  Retired  New York  Morning
# 3                2.0          13  Retired    Remote  Evening
# 4                5.0          16  Retired  New York  Evening
#
#    YearsWithCompany  Bonus  Salary_Normalized
# 0                 9  564.1           0.454500
# 1                 4  424.9           0.280020
# ...

# %% [markdown]
# ### TASK - 17
# ##### Adding a new column 'ExperienceLevel' which categorizes the 'Experience' into 'Junior', 'Mid' and 'Senior'.
# ___

# %%
df['ExperienceLevel'] = pd.cut(df['Experience'], bins=[0, 5, 10, float('inf')], labels=['Junior', 'Mid', 'Senior'])
df.head(5)
# Out:
#    ID                Name  Age  Gender Department  Salary Joining Date  \
# 0   1        Cory Escobar   48  Female         HR    5641   2015-05-03
# 1   2     Timothy Sanchez   25   Other      Sales    4249   2020-11-09
# 2   3        Chad Nichols   57   Other      Sales    3058   2019-02-12
# 3   4  Christine Williams   58  Female         IT    5895   2017-09-08
# 4   5        Amber Harris   35   Other         IT    4317   2020-02-15
#
#    Performance Score  Experience   Status  Location  Session  \
# 0                2.0          16   Active    Remote    Night
# 1                2.0          11  Retired    Remote  Evening
# 2                NaN           2  Retired  New York  Morning
# 3                2.0          13  Retired    Remote  Evening
# 4                5.0          16  Retired  New York  Evening
#
#    YearsWithCompany  Bonus  Salary_Normalized ExperienceLevel
# 0                 9  564.1           0.454500          Senior
# ...

# %% [markdown]
# ### TASK - 18
# ##### Adding a new row to the DataFrame.
# ___

# %%
new_row = {'Name': 'New Employee', 'Age': 30, 'Salary': 6000, 'Experience': 5, 
           'Department': 'HR', 'Performance Score': 4, 'Status': 'Active'}
new_row_df = pd.DataFrame([new_row])
df = pd.concat([df, new_row_df], ignore_index=True)
df.tail(5)
# Out:
#           ID             Name  Age  Gender Department  Salary Joining Date  \
# 996    997.0     Todd Johnson   29  Female      Sales    6754   2018-07-20
# 997    998.0  Michael Sanchez   18    Male      Sales    5278   2023-07-05
# 998    999.0    Ashley Taylor   51  Female         IT    5437   2022-02-18
# 999   1000.0      Shawn Scott   45    Male         IT    7364   2022-07-31
# 1000     NaN     New Employee   30     NaN         HR    6000          NaT
#
#       Performance Score  Experience   Status     Location  Session  \
# 996                 NaN          12  Retired     New York  Morning
# 997                 5.0           3   Active     New York  Morning
# 998                 4.0           9  Retired  Los Angeles  Evening
# 999                 2.0           4   Active       Remote  Morning
# 1000                4.0           5   Active          NaN      NaN
#
#       YearsWithCompany  Bonus  Salary_Normalized ExperienceLevel
# ...

# %% [markdown]
# ### TASK - 19
# ##### Removing the 'Session' column from the DataFrame.
# ___

# %%
df = df.drop(columns=['Session'])
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Gender', 'Department', 'Salary', 'Joining Date',
#        'Performance Score', 'Experience', 'Status', 'Location',
#        'YearsWithCompany', 'Bonus', 'Salary_Normalized', 'ExperienceLevel'],
#       dtype='object')

# %% [markdown]
# ### TASK - 20
# ##### Removing the rows where the 'Age' is greater than 60.
# ___

# %%
df = df[df['Age'] <= 60]
df.head(5)
# Out:
#     ID                Name  Age  Gender Department  Salary Joining Date  \
# 0  1.0        Cory Escobar   48  Female         HR    5641   2015-05-03
# 1  2.0     Timothy Sanchez   25   Other      Sales    4249   2020-11-09
# 2  3.0        Chad Nichols   57   Other      Sales    3058   2019-02-12
# 3  4.0  Christine Williams   58  Female         IT    5895   2017-09-08
# 4  5.0        Amber Harris   35   Other         IT    4317   2020-02-15
#
#    Performance Score  Experience   Status  Location  YearsWithCompany  Bonus  \
# 0                2.0          16   Active    Remote               9.0  564.1
# 1                2.0          11  Retired    Remote               4.0  424.9
# 2                NaN           2  Retired  New York               5.0  305.8
# 3                2.0          13  Retired    Remote               7.0  589.5
# 4                5.0          16  Retired  New York               4.0  431.7
#
#    Salary_Normalized ExperienceLevel
# ...

# %% [markdown]
# ### TASK - 21
# ##### Adding a new column 'AgeGroup' which categorizes the 'Age' into 'Young', 'Middle-aged' and 'Senior'.
# ___

# %%
df['AgeGroup'] = pd.cut(df['Age'], bins=[0, 30, 50, float('inf')], labels=['Young', 'Middle-aged', 'Senior'])

# %% [markdown]
# ### TASK - 22
# ##### Displaying the columns which have missing values.
# ___

# %%
missing_columns = df.isna().sum()
print(missing_columns[missing_columns > 0])
# Out:
# ID                     1
# Gender                 1
# Joining Date           1
# Performance Score    291
# Location               1
# YearsWithCompany       1
# Bonus                  1
# Salary_Normalized      1
# ExperienceLevel        1
# dtype: int64

# %% [markdown]
# ### TASK - 23
# ##### Replacing the missing values in 'Performance Score' column with the mean value.
# ___

# %%
df['Performance Score'] = df['Performance Score'].fillna(df['Performance Score'].mean())
df.head(5)
# Out:
#     ID                Name  Age  Gender Department  Salary Joining Date  \
# 0  1.0        Cory Escobar   48  Female         HR    5641   2015-05-03
# 1  2.0     Timothy Sanchez   25   Other      Sales    4249   2020-11-09
# 2  3.0        Chad Nichols   57   Other      Sales    3058   2019-02-12
# 3  4.0  Christine Williams   58  Female         IT    5895   2017-09-08
# 4  5.0        Amber Harris   35   Other         IT    4317   2020-02-15
#
#    Performance Score  Experience   Status  Location  YearsWithCompany  Bonus  \
# 0           2.000000          16   Active    Remote               9.0  564.1
# 1           2.000000          11  Retired    Remote               4.0  424.9
# 2           3.442786           2  Retired  New York               5.0  305.8
# 3           2.000000          13  Retired    Remote               7.0  589.5
# 4           5.000000          16  Retired  New York               4.0  431.7
#
#    Salary_Normalized ExperienceLevel     AgeGroup
# ...

# %% [markdown]
# ### TASK - 24
# ##### Removing the rows which have missing values.
# ___

# %%
df = df.dropna()

# %% [markdown]
# ### TASK - 25
# ##### Replacing the missing values in 'Performance Score' column with the median value of the respective 'Department'.
# ___

# %%
df['Performance Score'] = df.groupby('Department')['Performance Score'].transform(lambda x: x.fillna(x.median()))

# %% [markdown]
# ### TASK - 26
# ##### Displaying the employees from 'IT' department whose 'Age' is greater than the average age of 'IT' department.
# ___

# %%
it_avg_age = df[df['Department'] == 'IT']['Age'].mean()
df[(df['Department'] == 'IT') & (df['Age'] > it_avg_age)]
# Out:
#          ID                Name  Age  Gender Department  Salary Joining Date  \
# 3       4.0  Christine Williams   58  Female         IT    5895   2017-09-08
# 33     34.0    Mr. Brian Nelson   42  Female         IT    5207   2017-08-17
# 34     35.0            Lisa Fry   51  Female         IT    9259   2017-09-26
# 41     42.0      Charles Mccall   58   Other         IT    9512   2024-11-10
# 47     48.0        Jake Johnson   48   Other         IT    5848   2017-02-03
# ..      ...                 ...  ...     ...        ...     ...          ...
# 979   980.0    Crystal Espinoza   55  Female         IT    4952   2023-09-04
# 984   985.0        Jeffrey Hall   41   Other         IT    8768   2018-08-27
# 986   987.0     Melissa Bradley   39  Female         IT    9618   2015-07-05
# 998   999.0       Ashley Taylor   51  Female         IT    5437   2022-02-18
# 999  1000.0         Shawn Scott   45    Male         IT    7364   2022-07-31
#
# ...

# %% [markdown]
# ### TASK - 27
# ##### Removing the duplicate rows based on 'Name' and 'Joining Date'.
# ___

# %%
duplicates = df.duplicated(subset=['Name', 'Joining Date'], keep='first')
df = df[~duplicates]
df.head(5)
# Out:
#     ID                Name  Age  Gender Department  Salary Joining Date  \
# 0  1.0        Cory Escobar   48  Female         HR    5641   2015-05-03
# 1  2.0     Timothy Sanchez   25   Other      Sales    4249   2020-11-09
# 2  3.0        Chad Nichols   57   Other      Sales    3058   2019-02-12
# 3  4.0  Christine Williams   58  Female         IT    5895   2017-09-08
# 4  5.0        Amber Harris   35   Other         IT    4317   2020-02-15
#
#    Performance Score  Experience   Status  Location  YearsWithCompany  Bonus  \
# 0           2.000000          16   Active    Remote               9.0  564.1
# 1           2.000000          11  Retired    Remote               4.0  424.9
# 2           3.442786           2  Retired  New York               5.0  305.8
# 3           2.000000          13  Retired    Remote               7.0  589.5
# 4           5.000000          16  Retired  New York               4.0  431.7
#
#    Salary_Normalized ExperienceLevel     AgeGroup
# ...

# %% [markdown]
# ### TASK - 28
# ##### Removing the rows where 'Experience' is greater than 'Age' - 18.
# ___

# %%
df = df[df['Experience'] <= df['Age'] - 18]
df.head(5)
# Out:
#     ID                Name  Age  Gender Department  Salary Joining Date  \
# 0  1.0        Cory Escobar   48  Female         HR    5641   2015-05-03
# 2  3.0        Chad Nichols   57   Other      Sales    3058   2019-02-12
# 3  4.0  Christine Williams   58  Female         IT    5895   2017-09-08
# 4  5.0        Amber Harris   35   Other         IT    4317   2020-02-15
# 5  6.0         Ashley Howe   29  Female         HR    2591   2016-06-24
#
#    Performance Score  Experience   Status  Location  YearsWithCompany  Bonus  \
# 0           2.000000          16   Active    Remote               9.0  564.1
# 2           3.442786           2  Retired  New York               5.0  305.8
# 3           2.000000          13  Retired    Remote               7.0  589.5
# 4           5.000000          16  Retired  New York               4.0  431.7
# 5           1.000000           6   Active    Remote               8.0  259.1
#
#    Salary_Normalized ExperienceLevel     AgeGroup
# ...

# %% [markdown]
# ### TASK - 29
# ##### Sorting the DataFrame based on 'Salary' in descending order.
# ___

# %%
df = df.sort_values(by='Salary', ascending=False)
df.head(10)
# Out:
#         ID                Name  Age  Gender Department  Salary Joining Date  \
# 811  812.0        Jesse Miller   52    Male         HR    9993   2020-11-27
# 531  532.0  Jeffrey Williamson   54   Other         IT    9988   2015-12-08
# 937  938.0       Gary Mitchell   52  Female      Sales    9963   2016-09-22
# 908  909.0       Sara Martinez   34   Other         HR    9951   2024-02-18
# 120  121.0       David Hampton   39  Female         HR    9941   2024-07-06
# 200  201.0   Mr. James Johnson   48  Female         HR    9930   2019-08-04
# 796  797.0       Jacob Shannon   35   Other      Sales    9926   2016-09-04
# 250  251.0      Joshua Bullock   38    Male      Sales    9924   2019-01-10
# 289  290.0         Sara Stokes   30  Female         IT    9921   2018-10-01
# 758  759.0     Matthew Roberts   53    Male      Sales    9917   2017-07-07
#
#      Performance Score  Experience   Status     Location  YearsWithCompany  \
# ...

# %% [markdown]
# ### TASK - 30
# ##### Sorting the DataFrame based on 'Department' and 'Joining Date' in ascending order.
# ___

# %%
df = df.sort_values(by=['Department', 'Joining Date'], ascending=[True, True])
df.head(10)
# Out:
#         ID                   Name  Age  Gender Department  Salary  \
# 514  515.0      Taylor Williamson   48    Male         HR    9293
# 11    12.0      Rodney Richardson   60   Other         HR    6908
# 7      8.0           Amanda Baker   52   Other         HR    6285
# 677  678.0        Michelle Durham   35    Male         HR    5900
# 0      1.0           Cory Escobar   48  Female         HR    5641
# 728  729.0          Linda Hawkins   60   Other         HR    4524
# 330  331.0              Juan Dean   39    Male         HR    6830
# 417  418.0           Angel Fuller   39    Male         HR    3677
# 367  368.0              Adam Lane   20   Other         HR    7485
# 513  514.0  Miss Alyssa Perez DDS   59   Other         HR    8297
#
#     Joining Date  Performance Score  Experience   Status     Location  \
# 514   2015-03-10           3.442786          17  Retired      Chicago
# 11    2015-03-14           4.000000          19   Active      Chicago
# ...

# %% [markdown]
# ### TASK - 31
# ##### Adding a new column 'SalaryRank' which ranks the 'Salary' within each 'Department' in descending order.
# ___

# %%
df['SalaryRank'] = df.groupby('Department')['Salary'].rank(ascending=False)
df.head(10)
# Out:
#         ID                   Name  Age  Gender Department  Salary  \
# 514  515.0      Taylor Williamson   48    Male         HR    9293
# 11    12.0      Rodney Richardson   60   Other         HR    6908
# 7      8.0           Amanda Baker   52   Other         HR    6285
# 677  678.0        Michelle Durham   35    Male         HR    5900
# 0      1.0           Cory Escobar   48  Female         HR    5641
# 728  729.0          Linda Hawkins   60   Other         HR    4524
# 330  331.0              Juan Dean   39    Male         HR    6830
# 417  418.0           Angel Fuller   39    Male         HR    3677
# 367  368.0              Adam Lane   20   Other         HR    7485
# 513  514.0  Miss Alyssa Perez DDS   59   Other         HR    8297
#
#     Joining Date  Performance Score  Experience   Status     Location  \
# 514   2015-03-10           3.442786          17  Retired      Chicago
# 11    2015-03-14           4.000000          19   Active      Chicago
# ...

# %% [markdown]
# ### TASK - 32
# ##### Sorting the DataFrame based on 'Experience' in descending order and 'Performance Score' in ascending order.
# ___

# %%
df = df.sort_values(by=['Experience', 'Performance Score'], ascending=[False, True])
df.head(10)
# Out:
#         ID              Name  Age  Gender Department  Salary Joining Date  \
# 538  539.0    Brandon Church   38    Male         HR    8388   2021-08-02
# 355  356.0    Laura Castillo   41    Male         IT    2392   2024-03-15
# 402  403.0     Briana Martin   59    Male      Sales    4496   2023-05-22
# 828  829.0    Michael Snyder   55   Other      Sales    7497   2024-02-03
# 529  530.0        Katie Vega   40  Female         HR    7002   2019-08-06
# 808  809.0   Matthew Bonilla   44    Male         IT    9092   2018-06-11
# 854  855.0         Amy Heath   54    Male      Sales    6897   2021-01-02
# 765  766.0       Steve Smith   42  Female      Sales    3414   2023-02-13
# 287  288.0     Michele Roman   60   Other         HR    3162   2017-06-14
# 544  545.0  Elizabeth Watson   47  Female         HR    2766   2018-10-11
#
#      Performance Score  Experience   Status     Location  YearsWithCompany  \
# 538           1.000000          20  Retired       Remote               3.0
# ...

# %% [markdown]
# ### TASK - 33
# ##### Displaying the employees from 'HR' department whose 'Salary' is greater than 5000.
# ___

# %%
hr_df = df[(df['Department'] == 'HR') & (df['Salary'] > 5000)]
hr_df
# Out:
#         ID                   Name  Age  Gender Department  Salary  \
# 538  539.0         Brandon Church   38    Male         HR    8388
# 529  530.0             Katie Vega   40  Female         HR    7002
# 330  331.0              Juan Dean   39    Male         HR    6830
# 870  871.0            Nicole Cook   41  Female         HR    8495
# 165  166.0           Caleb Coffey   49   Other         HR    6194
# ..     ...                    ...  ...     ...        ...     ...
# 119  120.0         Heidi Franklin   22    Male         HR    7187
# 513  514.0  Miss Alyssa Perez DDS   59   Other         HR    8297
# 599  600.0          Stephen Weber   20    Male         HR    7375
# 643  644.0          Rebecca Avery   40  Female         HR    6918
# 732  733.0              Jay Evans   21    Male         HR    8147
#
#     Joining Date  Performance Score  Experience   Status     Location  \
# 538   2021-08-02           1.000000          20  Retired       Remote
# ...

# %% [markdown]
# ### TASK - 34
# ##### Removing the rows where the 'Location' is 'Chicago'.
# ___

# %%
df = df[df['Location'] != 'Chicago']
print(df)
# Out:
#         ID                     Name  Age  Gender Department  Salary  \
# 538  539.0           Brandon Church   38    Male         HR    8388
# 355  356.0           Laura Castillo   41    Male         IT    2392
# 402  403.0            Briana Martin   59    Male      Sales    4496
# 828  829.0           Michael Snyder   55   Other      Sales    7497
# 529  530.0               Katie Vega   40  Female         HR    7002
# ..     ...                      ...  ...     ...        ...     ...
# 709  710.0              Jacob Woods   54  Female         IT    9592
# 651  652.0           Julian Maxwell   47  Female         IT    3343
# 438  439.0         Mrs. Lisa Suarez   56    Male         IT    8236
# 143  144.0              Dana Potter   46    Male         IT    6368
# 491  492.0  Dr. Jacob Castaneda DVM   53   Other      Sales    9181
#
#     Joining Date  Performance Score  Experience   Status     Location  \
# 538   2021-08-02                1.0          20  Retired       Remote
# ...

# %% [markdown]
# ### TASK - 35
# ##### Removing the rows where the 'Performance Score' is less than 2.
# ___

# %%
df = df[df['Performance Score'] >= 2]
print(df)
# Out:
#         ID                     Name  Age  Gender Department  Salary  \
# 529  530.0               Katie Vega   40  Female         HR    7002
# 808  809.0          Matthew Bonilla   44    Male         IT    9092
# 854  855.0                Amy Heath   54    Male      Sales    6897
# 765  766.0              Steve Smith   42  Female      Sales    3414
# 287  288.0            Michele Roman   60   Other         HR    3162
# ..     ...                      ...  ...     ...        ...     ...
# 709  710.0              Jacob Woods   54  Female         IT    9592
# 651  652.0           Julian Maxwell   47  Female         IT    3343
# 438  439.0         Mrs. Lisa Suarez   56    Male         IT    8236
# 143  144.0              Dana Potter   46    Male         IT    6368
# 491  492.0  Dr. Jacob Castaneda DVM   53   Other      Sales    9181
#
#     Joining Date  Performance Score  Experience   Status     Location  \
# 529   2019-08-06           2.000000          20   Active       Remote
# ...

# %% [markdown]
# ### TASK - 36
# ##### Displaying the average salary of each 'Department'.
# ___

# %%
avg_salary_by_department = df.groupby('Department')['Salary'].mean()
print(avg_salary_by_department)
# Out:
# Department
# HR       5989.500000
# IT       5814.593548
# Sales    5940.811594
# Name: Salary, dtype: float64

# %% [markdown]
# ### TASK - 37
# ##### Displaying the total salary of each 'Status'.
# ___

# %%
total_salary_by_status = df.groupby('Status')['Salary'].sum()
print(total_salary_by_status)
# Out:
# Status
# Active     1206997
# Retired    1256795
# Name: Salary, dtype: int64

# %% [markdown]
# ### TASK - 38
# ##### Displaying the maximum performance score of each 'Location'.
# ___

# %%
max_perf_by_location = df.groupby('Location')['Performance Score'].max()
print(max_perf_by_location)
# Out:
# Location
# Los Angeles    5.0
# New York       5.0
# Remote         2.0
# Name: Performance Score, dtype: float64

# %% [markdown]
# ### TASK - 39
# ##### Displaying the total salary of each 'Joining Year'.
# ___

# %%
df['Joining Year'] = df['Joining Date'].dt.year
total_salary_by_year = df.groupby('Joining Year')['Salary'].sum()
print(total_salary_by_year)
# Out:
# Joining Year
# 2014     15135
# 2015    183612
# 2016    224542
# 2017    229453
# 2018    328109
# 2019    239013
# 2020    213576
# 2021    263590
# 2022    216888
# 2023    296657
# 2024    253217
# Name: Salary, dtype: int64

# %% [markdown]
# ### TASK - 40
# ##### Displaying the average performance score of each 'Department'.
# ___

# %%
avg_perf_by_dept = df.groupby('Department')['Performance Score'].mean()
best_department = avg_perf_by_dept.idxmax()
print(best_department)
# Out:
# IT

# %% [markdown]
# ### TASK - 41
# ##### Displaying the count of employees in each 'Location' and 'Status'.
# ___

# %%
df.groupby(['Location', 'Status'])['Name'].count()
# Out:
# Location     Status
# Los Angeles  Active     85
#              Retired    86
# New York     Active     78
#              Retired    87
# Remote       Active     43
#              Retired    38
# Name: Name, dtype: int64

# %% [markdown]
# ### TASK - 42
# ##### Displaying the sum, mean and standard deviation of salary for each 'Status'.
# ___

# %%
salary_stats = df.groupby('Status')['Salary'].agg(['sum', 'mean', 'std'])
print(salary_stats)
# Out:
#              sum         mean          std
# Status
# Active   1206997  5859.208738  2356.802133
# Retired  1256795  5956.374408  2334.318738

# %% [markdown]
# ### TASK - 43
# ##### Adding a new column 'MonthlySalary' which is the monthly salary of each employee.
# ___

# %%
df['MonthlySalary'] = df['Salary'].apply(lambda x: x / 12)
print(df)
# Out:
#         ID                     Name  Age  Gender Department  Salary  \
# 529  530.0               Katie Vega   40  Female         HR    7002
# 808  809.0          Matthew Bonilla   44    Male         IT    9092
# 854  855.0                Amy Heath   54    Male      Sales    6897
# 765  766.0              Steve Smith   42  Female      Sales    3414
# 287  288.0            Michele Roman   60   Other         HR    3162
# ..     ...                      ...  ...     ...        ...     ...
# 709  710.0              Jacob Woods   54  Female         IT    9592
# 651  652.0           Julian Maxwell   47  Female         IT    3343
# 438  439.0         Mrs. Lisa Suarez   56    Male         IT    8236
# 143  144.0              Dana Potter   46    Male         IT    6368
# 491  492.0  Dr. Jacob Castaneda DVM   53   Other      Sales    9181
#
#     Joining Date  Performance Score  Experience   Status     Location  \
# 529   2019-08-06           2.000000          20   Active       Remote
# ...

# %% [markdown]
# ### TASK - 44
# ##### Converting all the strings in the DataFrame to uppercase.
# ___

# %%
df = df.applymap(lambda x: x.upper() if isinstance(x, str) else x)
print(df)
# Out:
#         ID                     Name  Age  Gender Department  Salary  \
# 529  530.0               KATIE VEGA   40  FEMALE         HR    7002
# 808  809.0          MATTHEW BONILLA   44    MALE         IT    9092
# 854  855.0                AMY HEATH   54    MALE      SALES    6897
# 765  766.0              STEVE SMITH   42  FEMALE      SALES    3414
# 287  288.0            MICHELE ROMAN   60   OTHER         HR    3162
# ..     ...                      ...  ...     ...        ...     ...
# 709  710.0              JACOB WOODS   54  FEMALE         IT    9592
# 651  652.0           JULIAN MAXWELL   47  FEMALE         IT    3343
# 438  439.0         MRS. LISA SUAREZ   56    MALE         IT    8236
# 143  144.0              DANA POTTER   46    MALE         IT    6368
# 491  492.0  DR. JACOB CASTANEDA DVM   53   OTHER      SALES    9181
#
#     Joining Date  Performance Score  Experience   Status     Location  \
# 529   2019-08-06           2.000000          20   ACTIVE       REMOTE
# ...

# %% [markdown]
# ### TASK - 45
# ##### Merging the DataFrame with the 'budget_data' DataFrame on 'Department'.
# ___

# %%
budget_data = pd.DataFrame({
    'Department': ['HR', 'IT', 'Sales'],
    'Budget': [100000, 200000, 150000]
})
df = pd.merge(df, budget_data, on='Department', how='inner')
print(df)
# Out:
#         ID               Name  Age  Gender Department  Salary Joining Date  \
# 0    530.0         KATIE VEGA   40  FEMALE         HR    7002   2019-08-06
# 1    809.0    MATTHEW BONILLA   44    MALE         IT    9092   2018-06-11
# 2    288.0      MICHELE ROMAN   60   OTHER         HR    3162   2017-06-14
# 3    545.0   ELIZABETH WATSON   47  FEMALE         HR    2766   2018-10-11
# 4    331.0          JUAN DEAN   39    MALE         HR    6830   2015-06-28
# ..     ...                ...  ...     ...        ...     ...          ...
# 274   14.0  BENJAMIN CALLAHAN   34    MALE         IT    5593   2019-06-23
# 275  710.0        JACOB WOODS   54  FEMALE         IT    9592   2020-06-03
# 276  652.0     JULIAN MAXWELL   47  FEMALE         IT    3343   2022-01-26
# 277  439.0   MRS. LISA SUAREZ   56    MALE         IT    8236   2023-11-06
# 278  144.0        DANA POTTER   46    MALE         IT    6368   2024-04-07
#
# ...

# %% [markdown]
# ### TASK - 46
# ##### Merging the DataFrame with the 'projects_data' DataFrame on 'ID'.
# ___

# %%
projects_data = pd.DataFrame({
    'ID': [1, 2, 3],
    'RecentProjects': [5, 3, 4]
})
df = pd.merge(df, projects_data, on='ID', how='inner')
print(df)
# Out:
#     ID          Name  Age  Gender Department  Salary Joining Date  \
# 0  1.0  CORY ESCOBAR   48  FEMALE         HR    5641   2015-05-03
#
#    Performance Score  Experience  Status  ... YearsWithCompany  Bonus  \
# 0                2.0          16  ACTIVE  ...              9.0  564.1
#
#    Salary_Normalized  ExperienceLevel     AgeGroup SalaryRank  Joining Year  \
# 0             0.4545           SENIOR  MIDDLE-AGED      114.0          2015
#
#    MonthlySalary  Budget  RecentProjects
# 0     470.083333  100000               5
#
# [1 rows x 21 columns]

# %% [markdown]
# ### TASK - 47
# ##### Merging the DataFrame with the 'team_leads' DataFrame on 'Department'.
# ___

# %%
team_leads = pd.DataFrame({
    'Department': ['HR', 'IT', 'Sales'],
    'TeamLead': ['Alice', 'Bob', 'Charlie']
})
df = pd.merge(df, team_leads, on='Department', how='left')
print(df)
# Out:
#     ID          Name  Age  Gender Department  Salary Joining Date  \
# 0  1.0  CORY ESCOBAR   48  FEMALE         HR    5641   2015-05-03
#
#    Performance Score  Experience  Status  ...  Bonus  Salary_Normalized  \
# 0                2.0          16  ACTIVE  ...  564.1             0.4545
#
#    ExperienceLevel     AgeGroup SalaryRank Joining Year  MonthlySalary  \
# 0           SENIOR  MIDDLE-AGED      114.0         2015     470.083333
#
#    Budget  RecentProjects  TeamLead
# 0  100000               5     Alice
#
# [1 rows x 22 columns]

# %% [markdown]
# ### TASK - 48
# ##### Adding a new column 'SalaryPerProject' which is the 'Salary' divided by 'RecentProjects'.
# ___

# %%
project_counts = pd.DataFrame({
    'ID': [1, 2, 3],
    'ProjectCount': [3, 5, 2]
})
df = pd.merge(df, project_counts, on='ID', how='left')
df['SalaryPerProject'] = df['Salary'] / df['ProjectCount']
print(df)
# Out:
#     ID          Name  Age  Gender Department  Salary Joining Date  \
# 0  1.0  CORY ESCOBAR   48  FEMALE         HR    5641   2015-05-03
#
#    Performance Score  Experience  Status  ... ExperienceLevel     AgeGroup  \
# 0                2.0          16  ACTIVE  ...          SENIOR  MIDDLE-AGED
#
#    SalaryRank  Joining Year MonthlySalary  Budget  RecentProjects  TeamLead  \
# 0       114.0          2015    470.083333  100000               5     Alice
#
#    ProjectCount  SalaryPerProject
# 0             3       1880.333333
#
# [1 rows x 24 columns]

# %% [markdown]
# ## TASK - 49
# ##### Adding a new column 'DeptAvgSalary' which is the average salary of each 'Department'.
# ___

# %%
df['DeptAvgSalary'] = df.groupby('Department')['Salary'].transform('mean')
df['SalaryIncrease%'] = ((df['Salary'] - df['DeptAvgSalary']) / df['DeptAvgSalary']) * 100
print(df)
# Out:
#     ID          Name  Age  Gender Department  Salary Joining Date  \
# 0  1.0  CORY ESCOBAR   48  FEMALE         HR    5641   2015-05-03
#
#    Performance Score  Experience  Status  ... SalaryRank  Joining Year  \
# 0                2.0          16  ACTIVE  ...      114.0          2015
#
#    MonthlySalary  Budget RecentProjects TeamLead  ProjectCount  \
# 0     470.083333  100000              5    Alice             3
#
#    SalaryPerProject  DeptAvgSalary  SalaryIncrease%
# 0       1880.333333         5641.0              0.0
#
# [1 rows x 26 columns]

# %% [markdown]
# ### TASK - 50
# ___

# %%
print('------THANKYOU-------')
# Out:
# ------THANKYOU-------
